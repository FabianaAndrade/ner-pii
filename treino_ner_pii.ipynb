# %% [markdown]
# <a href="https://colab.research.google.com/github/FabianaAndrade/ner-pii/blob/main/treino_ner_pii.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title
# !pip install -U transformers seqeval faker

# %%
import numpy as np
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import BertForSequenceClassification, BertTokenizer, pipeline
from transformers import AutoTokenizer, AutoModelForTokenClassification, TrainingArguments, Trainer
from sklearn import preprocessing
from seqeval.metrics import precision_score, recall_score, f1_score

# %%
device = torch.device("cuda:0" if (torch.cuda.is_available()) else "cpu")
print("device: ", device)

# %%
df_names = pd.read_csv('/content/all-pt-br-names.csv')
coluna = df_names.columns[1]
df_names[coluna].dropna().to_csv("nomes.txt", index=False, header=False)

# %%
print("numero de exemplos: ", len(df_names))

# %%
def load_lexicon(path):
    with open(path, encoding="utf-8") as f:
        return [l.strip() for l in f if l.strip()]
sobrenomes = load_lexicon("/content/portuguese_surnames.txt")
nomes = load_lexicon("/content/nomes.txt")

# %%
import random
import json
from faker import Faker

NUM_EXAMPLES = 5000
VAL_RATIO = 0.1
OUTPUT_TRAIN = "train.json"
OUTPUT_VAL = "validation.json"

fake = Faker("pt_BR")

TEMPLATES = [
    "Ontem encontrei {nome}.",
    "O {nome} foi ao mercado.",
    "A {nome} chegou cedo.",
    "Hoje {nome} está no trabalho.",
    "Você conhece {nome}?",
    "{nome} comprou um carro novo.",
    "Falei com {nome} ontem.",
    "O relatório foi entregue por {nome}.",
    "A mãe de {nome} chegou agora.",
    "Ontem vi {nome} no shopping.",
    "{nome} e {nome2} viajaram juntos.",
    "Fui ao cinema com {nome}.",
    "O {nome} e {nome2} participaram da reunião.",
    "{nome} mora em {cidade}.",
    "{nome} enviou uma mensagem para {nome2} ontem."
]

def tokenize(sentence):
    return sentence.replace(".", " .").replace(",", " ,").split()

dataset = []

for _ in range(NUM_EXAMPLES):
    nome = random.choice(nomes).title()
    if random.random() < 0.5:
        nome += " " + random.choice(sobrenomes).title()

    nome2 = None
    if random.random() < 0.3:
        nome2 = random.choice(nomes).title()
        if random.random() < 0.5:
            nome2 += " " + random.choice(sobrenomes).title()

    cidade = fake.city()

    template = random.choice(TEMPLATES)
    sentence = template.format(nome=nome, nome2=nome2 or "", cidade=cidade)
    sentence = " ".join(sentence.split())
    tokens = tokenize(sentence)

    tags = ["O"] * len(tokens)

    nome_tokens = nome.split()
    try:
        start_idx = tokens.index(nome_tokens[0])
        for i, t in enumerate(nome_tokens):
            tags[start_idx + i] = "B-PER" if i == 0 else "I-PER"
    except ValueError:
        pass

    if nome2:
        nome2_tokens = nome2.split()
        try:
            start_idx2 = tokens.index(nome2_tokens[0])
            for i, t in enumerate(nome2_tokens):
                tags[start_idx2 + i] = "B-PER" if i == 0 else "I-PER"
        except ValueError:
            pass

    dataset.append({"tokens": tokens, "tags": tags})

random.shuffle(dataset)
n_val = int(len(dataset) * VAL_RATIO)
val = dataset[:n_val]
train = dataset[n_val:]

with open(OUTPUT_TRAIN, "w", encoding="utf-8") as f:
    json.dump(train, f, indent=2, ensure_ascii=False)
with open(OUTPUT_VAL, "w", encoding="utf-8") as f:
    json.dump(val, f, indent=2, ensure_ascii=False)

print(f"Gerado {len(train)} frases de treino / {len(val)} frases de validação")

# %%
train
# Out:
# [{'tokens': ['Você', 'conhece', 'Kewry?'], 'tags': ['O', 'O', 'O']},
#  {'tokens': ['Hoje', 'Vadenildo', 'está', 'no', 'trabalho', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Nauani', 'Madeira', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Eleude', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Falei', 'com', 'Anatil', 'Vilarinho', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O']},
#  {'tokens': ['A', 'Anadilia', 'Meira', 'chegou', 'cedo', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Sirso?'], 'tags': ['O', 'O', 'O']},
#  {'tokens': ['O', 'Dayane', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O',
#    'Cleudsom',
#    'Barroqueiro',
#    'e',
#    'participaram',
#    'da',
#    'reunião',
#    '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Jilce', 'e', 'participaram', 'da', 'reunião', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Ilion', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Izequel?'], 'tags': ['O', 'O', 'O']},
#  {'tokens': ['Renana', 'e', 'Ercilei', 'Graça', 'viajaram', 'juntos', '.'],
#   'tags': ['B-PER', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Sizernandes', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Falei', 'com', 'Gilsara', 'Farinha', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O']},
#  {'tokens': ['O',
#    'relatório',
#    'foi',
#    'entregue',
#    'por',
#    'Izakiel',
#    'Saloio',
#    '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['Giovanio', 'e', 'Audemario', 'Porto', 'viajaram', 'juntos', '.'],
#   'tags': ['B-PER', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Chrislayne',
#    'Linhares',
#    'enviou',
#    'uma',
#    'mensagem',
#    'para',
#    'ontem',
#    '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Dionia', 'enviou', 'uma', 'mensagem', 'para', 'ontem', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Alacrino', 'Grangeia', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Hoje', 'Bertone', 'Salazar', 'está', 'no', 'trabalho', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ginomar',
#    'enviou',
#    'uma',
#    'mensagem',
#    'para',
#    'Heluo',
#    'Grilo',
#    'ontem',
#    '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O']},
#  {'tokens': ['Edelene', 'Nascimento', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Jizelda', 'mora', 'em', 'Pastor', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['A', 'Erinalva', 'chegou', 'cedo', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['A', 'Androaldo', 'Teixeira', 'chegou', 'cedo', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Erodite', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Chisthian', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Gomercino', 'Jesus', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['Edjailton',
#    'Esparteiro',
#    'enviou',
#    'uma',
#    'mensagem',
#    'para',
#    'Lidervan',
#    'ontem',
#    '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O']},
#  {'tokens': ['A', 'Carlito', 'Torres', 'chegou', 'cedo', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Noemir', 'Gonçalves', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Delvia', 'Bezerril', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Kewry', 'e', 'viajaram', 'juntos', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Cineria?'], 'tags': ['O', 'O', 'O']},
#  {'tokens': ['A', 'Pither', 'Inácio', 'chegou', 'cedo', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Solivam', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Laueny', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Janielia', 'Alencar', 'mora', 'em', 'Ramos', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Jurassi', 'Brito', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Francismeire', 'Espírito', 'Santo', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Maralina', 'Cotrim', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Nikaelle', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Elzerina',
#    'Medeiros',
#    'e',
#    'Riccardo',
#    'viajaram',
#    'juntos',
#    '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['O',
#    'Silver',
#    'Dantas',
#    'e',
#    'Emilhy',
#    'participaram',
#    'da',
#    'reunião',
#    '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Lindonora', 'Saraiva', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Woton', 'Bugalho', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Valquirene', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Elienilda', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Elizaura', 'Bulhões', 'e', 'viajaram', 'juntos', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Rayllana', 'Ribeiro', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['Keulen', 'Vilaverde', 'e', 'viajaram', 'juntos', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Neilom',
#    'Quintana',
#    'enviou',
#    'uma',
#    'mensagem',
#    'para',
#    'Poliany',
#    'Mota',
#    'ontem',
#    '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O']},
#  {'tokens': ['O',
#    'relatório',
#    'foi',
#    'entregue',
#    'por',
#    'Jilnara',
#    'Guilheiro',
#    '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['Hyam', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O',
#    'Isabor',
#    'e',
#    'Makiko',
#    'participaram',
#    'da',
#    'reunião',
#    '.'],
#   'tags': ['O', 'B-PER', 'O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Enoy',
#    'enviou',
#    'uma',
#    'mensagem',
#    'para',
#    'Wevellin',
#    'ontem',
#    '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Keroline', 'Paz', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['O',
#    'Edvardo',
#    'Abranches',
#    'e',
#    'Jemerson',
#    'Vargas',
#    'participaram',
#    'da',
#    'reunião',
#    '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Lourivalda', 'Resende', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Harlete', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Rodinalva', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Deuzenir', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O']},
#  {'tokens': ['O',
#    'Eleica',
#    'Estrela',
#    'e',
#    'Adelino',
#    'participaram',
#    'da',
#    'reunião',
#    '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Bartolameu', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Falei', 'com', 'Olacio', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O']},
#  {'tokens': ['O', 'Nayury', 'Ramos', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Ajemira', 'Guerreiro', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Naedna', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Morghana', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Divael', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Hoje', 'Adrisson', 'está', 'no', 'trabalho', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Geyssa', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O']},
#  {'tokens': ['Estania', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Josaneide',
#    'Morgado',
#    'e',
#    'Analuiza',
#    'viajaram',
#    'juntos',
#    '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Egrinaldo', 'e', 'Ielio', 'viajaram', 'juntos', '.'],
#   'tags': ['B-PER', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Kauani', 'Mata', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Romenilda', 'Vilhena', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Anice', 'Domingues', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['Greciele', 'e', 'viajaram', 'juntos', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Dinifer', 'Corte-Real?'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Izelita', 'Alves', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['O',
#    'relatório',
#    'foi',
#    'entregue',
#    'por',
#    'Arnete',
#    'Zagalo',
#    '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['Você', 'conhece', 'Idnes', 'Alencastre?'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER']},
#  {'tokens': ['Elurdiane', 'Albernaz', 'e', 'viajaram', 'juntos', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Gleicykelly', 'Pinhal', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Islla', 'mora', 'em', 'Barbosa', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Adrielhe', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Gedel', 'Farias', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Teotino', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['A', 'Jumair', 'Naves', 'chegou', 'cedo', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Azeilda', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Ursina', 'mora', 'em', 'Mendes', 'de', 'Monteiro', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Kelverson', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Jurandi?'], 'tags': ['O', 'O', 'O']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Marcimiano', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Irielma', 'Homem', 'mora', 'em', 'Pires', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Criselite', 'Guerra', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Shales', 'Ramires', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Edeni', 'Carvalho', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Genoir', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Gresiane', 'Alencar', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Hoje', 'Juviliana', 'está', 'no', 'trabalho', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Camylla?'], 'tags': ['O', 'O', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Romelson', 'Pardo', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['O',
#    'Olice',
#    'Imperial',
#    'e',
#    'participaram',
#    'da',
#    'reunião',
#    '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Mikeias', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Hoje', 'Cecilda', 'Aragão', 'está', 'no', 'trabalho', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Regivanio?'], 'tags': ['O', 'O', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Maraceli', 'Padilha', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Orlanda', 'Jesus', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Waltr', 'e', 'viajaram', 'juntos', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Francinne', 'Ilha', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Oneida', 'Cordeiro', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O']},
#  {'tokens': ['O', 'Waldeane', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Melquisedec', 'Zarco', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Albion', 'Candeias', 'e', 'viajaram', 'juntos', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Elselia', 'Cesário', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Charize', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Walaci', 'Varela', 'e', 'viajaram', 'juntos', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Kiane',
#    'enviou',
#    'uma',
#    'mensagem',
#    'para',
#    'Murillo',
#    'ontem',
#    '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Ingrison', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Seth', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Jeraldina', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Deoni?'], 'tags': ['O', 'O', 'O']},
#  {'tokens': ['Advanilson',
#    'Landim',
#    'enviou',
#    'uma',
#    'mensagem',
#    'para',
#    'ontem',
#    '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Alonso', 'Baía', 'e', 'participaram', 'da', 'reunião', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Aelias', 'mora', 'em', 'Correia', 'das', 'Flores', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O',
#    'Klisma',
#    'e',
#    'Echilly',
#    'participaram',
#    'da',
#    'reunião',
#    '.'],
#   'tags': ['O', 'B-PER', 'O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Dedir', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Pulo', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Jocilan', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Merques', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Macksom', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Nadimara', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Francieda', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['O', 'Weslandia', 'e', 'participaram', 'da', 'reunião', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['A', 'Jessilane', 'Ximenes', 'chegou', 'cedo', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Niclei', 'Severo?'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER']},
#  {'tokens': ['Deiviana', 'e', 'viajaram', 'juntos', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Josildete', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Falei', 'com', 'Wilkie', 'Hilário', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O']},
#  {'tokens': ['Macelene', 'enviou', 'uma', 'mensagem', 'para', 'ontem', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Alielson', 'mora', 'em', 'Dias', 'de', 'Marques', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Uedna', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Kejinaldo', 'enviou', 'uma', 'mensagem', 'para', 'ontem', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Glaucivan', 'Estrela', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O']},
#  {'tokens': ['A', 'Ulisis', 'chegou', 'cedo', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Hoje', 'Jamysson', 'está', 'no', 'trabalho', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Ruama', 'Barroqueiro', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Alexsando', 'Azeredo', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Lianai', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Hoje', 'Carmelicia', 'está', 'no', 'trabalho', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Weliton',
#    'Sales',
#    'enviou',
#    'uma',
#    'mensagem',
#    'para',
#    'ontem',
#    '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Izaltino', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['A', 'Hivina', 'chegou', 'cedo', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Nahum', 'Dorneles', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Tommaso', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Roson', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Você', 'conhece', 'Izaquiele?'], 'tags': ['O', 'O', 'O']},
#  {'tokens': ['Glydson', 'enviou', 'uma', 'mensagem', 'para', 'ontem', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Mezaqui', 'Falcão', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Wenbley', 'Lins', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Roabe', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Valdeniria', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Alvonir', 'mora', 'em', 'Santos', 'da', 'Serra', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Ise', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O']},
#  {'tokens': ['O', 'Gildivam', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Hoje', 'Emael', 'Queiroga', 'está', 'no', 'trabalho', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Nidelce', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Eliedison', 'Faustino', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Sulevan', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Kin', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Jorbeson', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['A', 'Yorrani', 'Carvalhal', 'chegou', 'cedo', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['O',
#    'relatório',
#    'foi',
#    'entregue',
#    'por',
#    'Jesoaldo',
#    'Leitão',
#    '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['Maurivane', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Suelani', 'Durão?'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Mackael', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Falei', 'com', 'Alua', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O']},
#  {'tokens': ['O', 'Rauani', 'Brás', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Wellinjton',
#    'Faustino',
#    'enviou',
#    'uma',
#    'mensagem',
#    'para',
#    'ontem',
#    '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Kleybson',
#    'Mourão',
#    'enviou',
#    'uma',
#    'mensagem',
#    'para',
#    'ontem',
#    '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Edegilson', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Você', 'conhece', 'Aleildes?'], 'tags': ['O', 'O', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Kitia', 'Monteiro', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Andrili', 'mora', 'em', 'Cavalcanti', 'das', 'Flores', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Hendson', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Falei', 'com', 'Leonorio', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O']},
#  {'tokens': ['O', 'Jagna', 'e', 'participaram', 'da', 'reunião', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Alinete', 'mora', 'em', 'Cavalcante', 'Paulista', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['A',
#    'mãe',
#    'de',
#    'Odeildo',
#    'Carvalheira',
#    'chegou',
#    'agora',
#    '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Naziel', 'e', 'viajaram', 'juntos', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Marga', 'Parente?'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Cidna', 'Bogado', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Railany', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O']},
#  {'tokens': ['O', 'Alais', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Adenival', 'Doutel', 'mora', 'em', 'da', 'Rosa', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Kassimiro', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O']},
#  {'tokens': ['A', 'Josenilda', 'chegou', 'cedo', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Ysis', 'Amorim', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Regimaria', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Maianna', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['O', 'Josemario', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Saraiane', 'Castilhos', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Kelimar', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Deiziana', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Mairi', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Janizia', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Janemara', 'Guerra', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Misiele', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Erika', 'Diegues', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Adaulto', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O',
#    'relatório',
#    'foi',
#    'entregue',
#    'por',
#    'Rosevani',
#    'Mascarenhas',
#    '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['Hoje', 'Mamoru', 'Patrício', 'está', 'no', 'trabalho', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['A', 'Moacyr', 'chegou', 'cedo', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Dansley', 'Malheiro', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Juran', 'Rufino', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Webster', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Cirillo', 'Silva', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Leilianne', 'e', 'viajaram', 'juntos', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Kene', 'Paião', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['Saine',
#    'Olaio',
#    'enviou',
#    'uma',
#    'mensagem',
#    'para',
#    'ontem',
#    '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Yuria', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Alexssadro', 'Galante', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['O',
#    'Whilton',
#    'Rufino',
#    'e',
#    'participaram',
#    'da',
#    'reunião',
#    '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Edislei', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Marlani', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Falei', 'com', 'Khevyn', 'Santos', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O']},
#  {'tokens': ['O', 'Angieli', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Kaissa', 'Saldanha', 'mora', 'em', 'Leão', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O',
#    'Jalila',
#    'Camilo',
#    'e',
#    'participaram',
#    'da',
#    'reunião',
#    '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Ranieris', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Emillay', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['A', 'Dalvany', 'Semedo', 'chegou', 'cedo', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Inglidy', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Catricala', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Werly', 'Vale', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Moline', 'Campelo', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Dauri', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['A', 'Adelias', 'chegou', 'cedo', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['A', 'Raionara', 'Zarco', 'chegou', 'cedo', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Thalita', 'mora', 'em', 'Vasconcelos', 'de', 'Minas', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['A', 'Valsemir', 'Lobo', 'chegou', 'cedo', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Erlian', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O']},
#  {'tokens': ['Leidsom', 'mora', 'em', 'Pimenta', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Hoje', 'Casturina', 'Rua', 'está', 'no', 'trabalho', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O',
#    'relatório',
#    'foi',
#    'entregue',
#    'por',
#    'Claudii',
#    'Proença',
#    '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['Hoje', 'Divilson', 'Lampreia', 'está', 'no', 'trabalho', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Eliezeu?'], 'tags': ['O', 'O', 'O']},
#  {'tokens': ['O',
#    'Iellen',
#    'Sales',
#    'e',
#    'Marliceia',
#    'participaram',
#    'da',
#    'reunião',
#    '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Artulio', 'e', 'participaram', 'da', 'reunião', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Uanderson', 'enviou', 'uma', 'mensagem', 'para', 'ontem', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Jovercino', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Dadid', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Hoje', 'Georjia', 'Silveira', 'está', 'no', 'trabalho', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Laianna', 'Belém', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Arzelina', 'Mata?'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER']},
#  {'tokens': ['Você', 'conhece', 'Erina?'], 'tags': ['O', 'O', 'O']},
#  {'tokens': ['Izoleide',
#    'Viana',
#    'enviou',
#    'uma',
#    'mensagem',
#    'para',
#    'All',
#    'Viegas',
#    'ontem',
#    '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O']},
#  {'tokens': ['Arleno',
#    'França',
#    'enviou',
#    'uma',
#    'mensagem',
#    'para',
#    'ontem',
#    '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Hoje', 'Waldec', 'Pimentel', 'está', 'no', 'trabalho', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Warlas', 'Canto', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Rislaine', 'Severo', 'mora', 'em', 'Pastor', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['A', 'Leider', 'Torrado', 'chegou', 'cedo', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Zucleide', 'e', 'participaram', 'da', 'reunião', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Verusa', 'e', 'participaram', 'da', 'reunião', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Rainelson', 'mora', 'em', 'Costela', 'de', 'Minas', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Emanuelen?'], 'tags': ['O', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Elizabetr', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Ruinaldo', 'Costa', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Cimere', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Greisiane', 'Mata', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O']},
#  {'tokens': ['O', 'Arida', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Elisabeto', 'e', 'participaram', 'da', 'reunião', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ciciliana', 'Bulhões', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Aricelmo',
#    'Chagas',
#    'enviou',
#    'uma',
#    'mensagem',
#    'para',
#    'ontem',
#    '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Kauine', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Eluani', 'e', 'Ociomar', 'viajaram', 'juntos', '.'],
#   'tags': ['B-PER', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Quelcio', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Remisom', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['A', 'Renam', 'Cavalheiro', 'chegou', 'cedo', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Jullio', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Cleveson', 'e', 'viajaram', 'juntos', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Uelliton', 'Fitas', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Ordener', 'Cabral', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Traude', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O']},
#  {'tokens': ['O', 'Reulen', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O',
#    'Cleitiana',
#    'Simas',
#    'e',
#    'participaram',
#    'da',
#    'reunião',
#    '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Mail', 'Queiroga', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['Dinaldo', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Leornando', 'Infante', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O']},
#  {'tokens': ['O', 'Acivaldo', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Fabrizia', 'Macena', 'mora', 'em', 'Porto', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Geiovanni', 'e', 'participaram', 'da', 'reunião', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Tieni', 'Bessa', 'mora', 'em', 'Araújo', 'de', 'Goiás', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Glebe', 'Marques', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['O',
#    'relatório',
#    'foi',
#    'entregue',
#    'por',
#    'Alcilina',
#    'Beiriz',
#    '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['Rozenilton',
#    'Camelo',
#    'enviou',
#    'uma',
#    'mensagem',
#    'para',
#    'ontem',
#    '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['A',
#    'mãe',
#    'de',
#    'Denuza',
#    'Mascarenhas',
#    'chegou',
#    'agora',
#    '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['O',
#    'Deys',
#    'Portela',
#    'e',
#    'participaram',
#    'da',
#    'reunião',
#    '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['A', 'Aklla', 'chegou', 'cedo', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Rialino',
#    'Bragança',
#    'enviou',
#    'uma',
#    'mensagem',
#    'para',
#    'ontem',
#    '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Idani', 'Assis?'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Gessima', 'Pimentel', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Kalila', 'Ramos', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Glaudo', 'Corte-Real', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O',
#    'relatório',
#    'foi',
#    'entregue',
#    'por',
#    'Lygia',
#    'Guerra',
#    '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['O', 'Lindacira', 'e', 'participaram', 'da', 'reunião', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Hoje', 'Cleilce', 'Paula', 'está', 'no', 'trabalho', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Michela', 'Montenegro', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Hoje',
#    'Izildina',
#    'Souto',
#    'Maior',
#    'está',
#    'no',
#    'trabalho',
#    '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O',
#    'Maicira',
#    'Bragança',
#    'e',
#    'participaram',
#    'da',
#    'reunião',
#    '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Dely', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Genaide', 'e', 'viajaram', 'juntos', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Adelce', 'Vargas', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Valdeano', 'Baldaia', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['Elzuita', 'e', 'viajaram', 'juntos', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Auriel', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Eduado', 'Carvalheira', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Orleide', 'Torrado?'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER']},
#  {'tokens': ['Alvenice', 'e', 'viajaram', 'juntos', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Hoje', 'Pericles', 'Ulhoa', 'está', 'no', 'trabalho', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Adelma', 'Camacho', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Linair', 'mora', 'em', 'Melo', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Aelito', 'Fernandes', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Teodulina', 'e', 'participaram', 'da', 'reunião', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Suilane', 'Figueiró', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O']},
#  {'tokens': ['Beverly', 'Amaral', 'e', 'viajaram', 'juntos', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Onivaldo', 'Arruda', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Selatiel', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Laricy', 'Ferro', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Jilvanete', 'Ilha', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Lyse', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Margarette',
#    'Quintanilha',
#    'comprou',
#    'um',
#    'carro',
#    'novo',
#    '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Ketlhen', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O']},
#  {'tokens': ['Hoje', 'Rovaldo', 'está', 'no', 'trabalho', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Iramaria', 'Prado', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Klaiver', 'Botelho', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Argentina', 'Vilariça', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Anaeli', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Zanair', 'Holanda', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Elsenir',
#    'Pimenta',
#    'enviou',
#    'uma',
#    'mensagem',
#    'para',
#    'ontem',
#    '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Mariade', 'Cunha', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Elbi', 'e', 'participaram', 'da', 'reunião', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Allexia', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Neildo', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Dinorvan', 'França', 'mora', 'em', 'Moreira', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Carmona',
#    'Cordeiro',
#    'mora',
#    'em',
#    'Barros',
#    'do',
#    'Amparo',
#    '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Zilan', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Jessinara', 'e', 'participaram', 'da', 'reunião', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Hoje', 'Cineria', 'está', 'no', 'trabalho', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Euredes', 'Gomide', 'mora', 'em', 'da', 'Cruz', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Ivilla', 'Ferraço', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Alecandro', 'Ribas', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Josikely', 'Goulart', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['O', 'Eliaber', 'Lago', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Erval', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Jeciano', 'Ruas', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Walmy', 'Varejão', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Uedja', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Haidi', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Jeanet', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O',
#    'Natassya',
#    'Melgaço',
#    'e',
#    'participaram',
#    'da',
#    'reunião',
#    '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Maelia', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Aryon', 'mora', 'em', 'Alves', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Maudi', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Você', 'conhece', 'Nargila?'], 'tags': ['O', 'O', 'O']},
#  {'tokens': ['Cleiciely', 'Vilaverde', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O',
#    'Eliny',
#    'e',
#    'Helenides',
#    'participaram',
#    'da',
#    'reunião',
#    '.'],
#   'tags': ['O', 'B-PER', 'O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Valdey', 'mora', 'em', 'Câmara', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Riberson',
#    'Ferraço',
#    'enviou',
#    'uma',
#    'mensagem',
#    'para',
#    'ontem',
#    '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Gabino', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Greicilene', 'Boaventura', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Voldir', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Martieli', 'Gusmão', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Elina', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Hoje', 'Brenderson', 'está', 'no', 'trabalho', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Wilyan', 'mora', 'em', 'Sampaio', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Xarliane', 'mora', 'em', 'Santos', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O',
#    'relatório',
#    'foi',
#    'entregue',
#    'por',
#    'Delmacio',
#    'Gama',
#    '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Valcenira', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Falei', 'com', 'Durvaldo', 'Bonilha', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O']},
#  {'tokens': ['Hoje', 'Lillyan', 'está', 'no', 'trabalho', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Darcilene', 'Parreira', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O']},
#  {'tokens': ['Wendrel', 'Medina', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Tulia', 'Pontes', 'e', 'viajaram', 'juntos', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Thaysse?'], 'tags': ['O', 'O', 'O']},
#  {'tokens': ['Cielo', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Liuri', 'Penha', 'mora', 'em', 'Marques', 'de', 'Nogueira', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Caie', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Francisdo', 'Vilhena', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Dilea', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O']},
#  {'tokens': ['O', 'Arabel', 'Lobo', 'e', 'participaram', 'da', 'reunião', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Memorina', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Henique?'], 'tags': ['O', 'O', 'O']},
#  {'tokens': ['A', 'Wadila', 'chegou', 'cedo', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O']},
# ...
#  {'tokens': ['Jobs', 'enviou', 'uma', 'mensagem', 'para', 'ontem', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Clarete', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Você', 'conhece', 'Aldativa', 'Candeias?'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER']},
#  {'tokens': ['A', 'mãe', 'de', 'Luelly', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Havilla', 'enviou', 'uma', 'mensagem', 'para', 'ontem', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Gideon', 'Ávila', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['Você', 'conhece', 'Ronem?'], 'tags': ['O', 'O', 'O']},
#  {'tokens': ['Hoje', 'Laurim', 'Lousã', 'está', 'no', 'trabalho', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Jildo', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Oneize', 'Domingos', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ronivo', 'mora', 'em', 'Jesus', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Maurilucio', 'Vilhena', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Deuzinei', 'e', 'Selijane', 'viajaram', 'juntos', '.'],
#   'tags': ['B-PER', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Radassa', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Josivani', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O',
#    'Michelem',
#    'Monte',
#    'e',
#    'participaram',
#    'da',
#    'reunião',
#    '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Hoje', 'Hoel', 'está', 'no', 'trabalho', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Alarice', 'Lancastre', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Hoje', 'Hita', 'Nolasco', 'está', 'no', 'trabalho', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Adelandia', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O']},
#  {'tokens': ['O',
#    'Laurenildo',
#    'Carrilho',
#    'e',
#    'participaram',
#    'da',
#    'reunião',
#    '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Gemilsom', 'Fagundes', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Eliselma', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Eloh', 'Galante?'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Sherida', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Altanair', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Gislea', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['O', 'Arezia', 'e', 'participaram', 'da', 'reunião', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Ldo?'], 'tags': ['O', 'O', 'O']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Jiova', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Falei', 'com', 'Josilva', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Aderildo', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O']},
#  {'tokens': ['Raymar',
#    'Fitas',
#    'e',
#    'Airani',
#    'Saraiva',
#    'viajaram',
#    'juntos',
#    '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Jorgita', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Luize', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Hoje', 'Clarisvaldo', 'está', 'no', 'trabalho', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Jorga', 'Rodovalho', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Stanly', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Itaynara', 'Melgaço', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['A',
#    'mãe',
#    'de',
#    'Eribaldo',
#    'Travassos',
#    'chegou',
#    'agora',
#    '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Pyther', 'e', 'viajaram', 'juntos', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Adjacy', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Aldilina', 'Amaral', 'e', 'Cidinei', 'viajaram', 'juntos', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['A', 'Dauan', 'Vilalobos', 'chegou', 'cedo', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Suelbe', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Valmeir', 'e', 'viajaram', 'juntos', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Audemir', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Rodair', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Arismario', 'Holanda', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['O',
#    'Suelandia',
#    'Cabral',
#    'e',
#    'participaram',
#    'da',
#    'reunião',
#    '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Jayny', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Vandegilson',
#    'Pinheiro',
#    'enviou',
#    'uma',
#    'mensagem',
#    'para',
#    'Izolina',
#    'Freitas',
#    'ontem',
#    '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O']},
#  {'tokens': ['A', 'Aristenio', 'Ferrão', 'chegou', 'cedo', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Anitha', 'Paiva', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Helloany', 'Proença', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Hoje', 'Aleane', 'está', 'no', 'trabalho', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Joenes', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Neriane?'], 'tags': ['O', 'O', 'O']},
#  {'tokens': ['Hoje', 'Maxiel', 'está', 'no', 'trabalho', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O',
#    'relatório',
#    'foi',
#    'entregue',
#    'por',
#    'Schumacher',
#    'Castelo',
#    '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['O',
#    'relatório',
#    'foi',
#    'entregue',
#    'por',
#    'Indalesio',
#    'Rocha',
#    '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Libine', 'Cabral', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Gabrily', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Gelino', 'Gois', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['Falei', 'com', 'Derison', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O']},
#  {'tokens': ['Layanni', 'Inácio', 'mora', 'em', 'Dias', 'da', 'Prata', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Geniberto', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Basilo', 'Clementino', 'e', 'viajaram', 'juntos', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Eloida', 'Semedo', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['Janina', 'Ferraço', 'e', 'viajaram', 'juntos', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Jecionete', 'enviou', 'uma', 'mensagem', 'para', 'ontem', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Giezi', 'mora', 'em', 'Novais', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Eshily', 'mora', 'em', 'Azevedo', 'Paulista', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Solangea', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Dhione', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O']},
#  {'tokens': ['O', 'Jeron', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Louizy', 'Gentil', 'mora', 'em', 'da', 'Paz', 'do', 'Sul', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Heydi',
#    'Azeredo',
#    'mora',
#    'em',
#    'Correia',
#    'das',
#    'Flores',
#    '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Egton', 'Sesimbra', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['Você', 'conhece', 'Aglaise?'], 'tags': ['O', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Celesia', 'Olaio?'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER']},
#  {'tokens': ['Falei', 'com', 'Sidgley', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O']},
#  {'tokens': ['Ruzevel', 'Nazário', 'mora', 'em', 'Moura', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Arceli', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Inerio', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Jockson', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Ramin', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Gleuton?'], 'tags': ['O', 'O', 'O']},
#  {'tokens': ['Marliana', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Diangelo', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['O',
#    'Dimeson',
#    'e',
#    'Ivaneide',
#    'participaram',
#    'da',
#    'reunião',
#    '.'],
#   'tags': ['O', 'B-PER', 'O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Hoje', 'Isabeti', 'Palha', 'está', 'no', 'trabalho', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Jodielson', 'enviou', 'uma', 'mensagem', 'para', 'ontem', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['A', 'Ivaniza', 'chegou', 'cedo', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Hoje', 'Lulian', 'Pires', 'está', 'no', 'trabalho', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Onilsa',
#    'Lemes',
#    'enviou',
#    'uma',
#    'mensagem',
#    'para',
#    'ontem',
#    '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Rallison', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Iven', 'mora', 'em', 'Moreira', 'do', 'Norte', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Alonco?'], 'tags': ['O', 'O', 'O']},
#  {'tokens': ['A', 'Fracineide', 'chegou', 'cedo', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Edmarcio?'], 'tags': ['O', 'O', 'O']},
#  {'tokens': ['O',
#    'Alanys',
#    'Morais',
#    'e',
#    'Orsino',
#    'participaram',
#    'da',
#    'reunião',
#    '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['A', 'Estelane', 'chegou', 'cedo', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Generio', 'Madruga', 'e', 'viajaram', 'juntos', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Jesusnilson', 'Veríssimo?'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER']},
#  {'tokens': ['O', 'relatório', 'foi', 'entregue', 'por', 'Zelanda', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Prentice', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Hoje', 'Carlielson', 'está', 'no', 'trabalho', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['A', 'Claisa', 'Gago', 'chegou', 'cedo', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Persival', 'mora', 'em', 'Mendonça', '.'],
#   'tags': ['B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Falei', 'com', 'Verdi', 'Eanes', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O']},
#  {'tokens': ['O', 'Orestino', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Allanda', 'Vilela?'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER']},
#  {'tokens': ['Você', 'conhece', 'Sherlon', 'Sá?'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER']},
#  {'tokens': ['Ontem', 'vi', 'Rariza', 'Vidigal', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Odilse', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['A', 'mãe', 'de', 'Danieldo', 'Parente', 'chegou', 'agora', '.'],
#   'tags': ['O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Jefete', 'Porto', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Jucicler?'], 'tags': ['O', 'O', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Kevelin', 'Rocha', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Marcicleia', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Dhemison', 'e', 'participaram', 'da', 'reunião', '.'],
#   'tags': ['O', 'B-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['O', 'Danniela', 'Holanda', 'foi', 'ao', 'mercado', '.'],
#   'tags': ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Dieme', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Janilli', 'Gil', 'mora', 'em', 'Nogueira', 'do', 'Norte', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Rodynei', 'Vilas', 'Boas', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Gerismar?'], 'tags': ['O', 'O', 'O']},
#  {'tokens': ['Agilio', 'Girão', 'comprou', 'um', 'carro', 'novo', '.'],
#   'tags': ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Keilany', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Falei', 'com', 'Eliesio', 'Lamego', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'I-PER', 'O', 'O']},
#  {'tokens': ['Você', 'conhece', 'Adha?'], 'tags': ['O', 'O', 'O']},
#  {'tokens': ['Ontem', 'vi', 'Myreia', 'no', 'shopping', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O', 'O']},
#  {'tokens': ['Fui', 'ao', 'cinema', 'com', 'Lenilca', 'Penteado', '.'],
#   'tags': ['O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O']},
#  {'tokens': ['O',
#    'Jodison',
#    'e',
#    'Adrelly',
#    'César',
#    'participaram',
#    'da',
#    'reunião',
#    '.'],
#   'tags': ['O', 'B-PER', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O']},
#  {'tokens': ['Ontem', 'encontrei', 'Onedio', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O']},
#  {'tokens': ['Falei', 'com', 'Gertrudez', 'ontem', '.'],
#   'tags': ['O', 'O', 'B-PER', 'O', 'O']},
#  ...]

# %%
from datasets import load_dataset
dataset = load_dataset("json", data_files={"train": "/content/train.json"})

dataset = dataset["train"].train_test_split(test_size=0.1, seed=42)
dataset = {
    "train": dataset["train"],
    "validation": dataset["test"]
}

# %%
# @title
tokenizer = AutoTokenizer.from_pretrained('neuralmind/bert-base-portuguese-cased', use_fast=True)
LABELS = ["O", "B-PER", "I-PER"]
MODEL_NAME = "neuralmind/bert-base-portuguese-cased"  #BERTimbau
label2id = {label: i for i, label in enumerate(LABELS)}
id2label = {i: label for i, label in enumerate(LABELS)}

# %%
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(
        examples["tokens"],
        is_split_into_words=True,
        truncation=True,
        padding="max_length",
        max_length=128
    )

    labels = []
    for i, label in enumerate(examples["tags"]):
        word_ids = tokenized_inputs.word_ids(batch_index=i)
        label_ids = []
        previous_word_idx = None
        for word_idx in word_ids:
            if word_idx is None:
                label_ids.append(-100)
            elif word_idx != previous_word_idx:
                label_ids.append(label2id[label[word_idx]])
            else:
                if label[word_idx].startswith("B-"):
                    label_ids.append(label2id["I-PER"])
                else:
                    label_ids.append(label2id[label[word_idx]])
            previous_word_idx = word_idx
        labels.append(label_ids)

    tokenized_inputs["labels"] = labels
    return tokenized_inputs

tokenized_datasets = {}
tokenized_datasets["train"] = dataset["train"].map(tokenize_and_align_labels, batched=True)
tokenized_datasets["validation"] = dataset["validation"].map(tokenize_and_align_labels, batched=True)

# %%
model = AutoModelForTokenClassification.from_pretrained(
    MODEL_NAME,
    num_labels=len(LABELS),
    id2label=id2label,
    label2id=label2id
)

# %%
def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)
    true_labels = [
        [id2label[l] for l in label if l != -100] for label in labels
    ]
    true_predictions = [
        [id2label[pred] for (pred, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    return {
        "precision": precision_score(true_labels, true_predictions),
        "recall": recall_score(true_labels, true_predictions),
        "f1": f1_score(true_labels, true_predictions)
    }

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir="./bert-ner-pt",
    do_train=True,
    do_eval=True,
    eval_steps=500,
    logging_steps=200,
    save_steps=1000,
    learning_rate=3e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=16,
    num_train_epochs=3,
    weight_decay=0.01,
    logging_dir="./logs",
    fp16=True,
)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    compute_metrics=compute_metrics
)

trainer.train()

#691359bd154d080a0237473b0c555d1dccb4eda5

# %%
trainer.evaluate()

# %%
trainer.save_model("./bert-ner-pt")

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline

base_model = "neuralmind/bert-base-portuguese-cased"
model_path = "/content/bert-ner-pt/checkpoint-1521"

tokenizer = AutoTokenizer.from_pretrained(base_model)

model = AutoModelForTokenClassification.from_pretrained(model_path)

ner_pipeline = pipeline("ner", model=model, tokenizer=tokenizer, aggregation_strategy="simple")

# %%
text = "Fabiana foi a escola"
print(ner_pipeline(text))
# Out:
# [{'entity_group': 'PER', 'score': np.float32(0.99995244), 'word': 'Fabiana', 'start': 0, 'end': 7}]

# %%
text = "Andre and"
print(ner_pipeline(text))
# Out:
# [{'entity_group': 'PER', 'score': np.float32(0.9998152), 'word': 'Andre and', 'start': 0, 'end': 9}]

# %%
text = "rua rua"
print(ner_pipeline(text))
# Out:
# []
